# %%
print("Hello_from_first_project!")
# Out:
# Hello_from_first_project!

# %%
print("requires-python: 이 프로젝트가 정상적으로 작동하기 위한 최소한의 파이썬 버전을 지정합니다")
# Out:
# requires-python: 이 프로젝트가 정상적으로 작동하기 위한 최소한의 파이썬 버전을 지정합니다

# %%
print("name: 프로젝트의 이름을 지정합니다. 패키지 이름은 고유해야 합니다.")
# Out:
# name: 프로젝트의 이름을 지정합니다. 패키지 이름은 고유해야 합니다.
