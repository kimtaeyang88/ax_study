# %%
money = None

# %%
massage = """안녕하세요.
반갑습니다.
"""
type(massage)
# Out:
# str

# %%
# 코드 설명...
""" 주석
하나
둘
셋"""
# Out:
# ' 주석\n하나\n둘\n셋'

# %%
num = "100"
type(num)
# Out:
# str

# %%
int(num)+200
# Out:
# 300

# %%
"현재 시간은 " + 10 + "시"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 "현재 시간은 " + 10 + "시"
#
# TypeError: can only concatenate str (not "int") to str

# %%
"현재 시간은 " + str(10) + "시"
# Out:
# '현재 시간은 10시'

# %%
num1 = 100
num2 = 3.123
type(num1), type(num2)
# Out:
# (int, float)

# %%
num3 = num1 + num2
num3=num1+int(num2)

num3, type(num3)
# Out:
# (103, int)

# %%
time = "10"
if time.isdigit():
    int(time) + 1

# %%
message = "1"
if message:
    print("있음")
# Out:
# 있음

# %%
type(message)
# Out:
# str

# %%
result = bool(message)

result = type(result)

# %%
num1 = 10
num2 = 3

num1 // num2, num1 % num2
# Out:
# (3, 1)

# %%
num1 = 1000
num2 = 1000
id(num1), id(num2)
# Out:
# (1383400925136, 1383400926192)

# %%
num1 == num2 #동등성 비교
# Out:
# True

# %%
num1 is num2 # 동일성 비교(주소 비교)
# Out:
# False

# %%
# and
num1 = 20
result1 = num1 > 10
result2 = num1 < 100

result1 and result2
# Out:
# True

# %%
not (result1 and result2)
# Out:
# False

# %%
fruit1 = "apple"
fruit2 = "fear"

result1 = fruit1 == "apple"
result2 = fruit2 == "banana"

result1, result2
# Out:
# (True, False)

# %%
result1 or result2
# Out:
# True

# %%
result = True or 10**2
result
# Out:
# True

# %%
result = False or 10**2
result
# Out:
# 100

# %%
result = False or 10**2
result
# Out:
# 100

# %%
result = False or 10**2
result
# Out:
# 100

# %%
result = False or 10**2
result
# Out:
# 100

# %%
result = False and 10**2
result
# Out:
# False

# %%
message = ""

result = message or "기본 메세지"
result
# Out:
# '기본 메세지'

# %%
height = 170

result = height >= 165 and "크다"
result
# Out:
# '크다'

# %%
num = 1
num + 1
num + 1
num + 1
num
# Out:
# 1

# %%
num = 1
num += 1 
num += 1
num += 1
num
# Out:
# 4

# %%
num = 100
num2 = -num
num2
# Out:
# -100

# %%
num3 = -num2
num3
# Out:
# 100

# %%
message = "나의 이름은 %10s이고, 나이는 %d입니다."

message % ("철수", 20)
# Out:
# '나의 이름은         철수이고, 나이는 20입니다.'

# %%
message = "주문번호: %05d" %10
message
# Out:
# '주문번호: 00010'

# %%
# message = "숫자: %f" % 10.123456789
# message = "숫자: %.2f" % 10.123456789
# message = "숫자: %010.2f" % 10.123456789
message = "숫자: %010.2f" % 10.123456789
message
# Out:
# '숫자: 0000010.12'

# %%
message = "숫자: %d" % 10.12345
message
# Out:
# '숫자: 10'

# %%
message = "숫자: %s" % 10.12345
message
# Out:
# '숫자: 10.12345'

# %%
message = "내 이름은 {name}이고, 나이는 {0}입니다."
message.format(20, name="철수")
# Out:
# '내 이름은 철수이고, 나이는 20입니다.'

# %%
name = "영희"
age = 20

message = f"내 이름은 {name}이고, 나이는 {age}입니다"
message
# Out:
# '내 이름은 영희이고, 나이는 20입니다'

# %%
price = 10000
f"가격: {price:,}"
# Out:
# '가격: 10,000'

# %%
f"가격: {price:>10,}원"
# Out:
# '가격:     10,000원'

# %%
f"가격: {price:<10,}"
# Out:
# '가격: 10,000    '

# %%
name = "김태양"
age = 39

message = f"내 나이는 {name}이고, 나이는 {age}살입니다."
print(message)
# Out:
# 내 나이는 김태양이고, 나이는 39살입니다.

# %%
num1 = 10
num2 = 3.14
result = print(num1 + int(num2))
# Out:
# 13

# %%
user_input = "20"
if user_input.isdigit():
    age = int(user_input)
    print("정수 전환 성공")
else:
    print("숫자만 입력해 주세요!")
# Out:
# 정수 전환 성공

# %%
count = 10
count = count * 5
print(count)
# Out:
# 50

# %%
word1 = "apple"
word2 = "banana"

print(word1 < word2)
# Out:
# True

# %%
result = False and 500/0
print(result)
# Out:
# False

# %%
user_input = input("숫자를 입력하세요: ")
if user_input.isdigit():
    age = int(user_input)
    print("정수 전환 성공")
