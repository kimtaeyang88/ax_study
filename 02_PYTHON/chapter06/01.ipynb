# %%
import mod1
# Out:
# 결과: 30

# %%
mod1.add(10, 20)
# Out:
# 30

# %%
mod1.VERSION
# Out:
# '1.0.0'

# %%
import mod1 as m

m.add(10, 20)
# Out:
# 30

# %%
from mod1 import add, minus, VERSION

# %%
from mod1 import *
add(10, 20)
# Out:
# 30

# %%
from utils import mod2, mod3

mod2.multiply(10, 20)
# Out:
# 200

# %%
from utils.mod2 import multiply
multiply(10, 20)
# Out:
# 200

# %%
from utils.sub.mod3 import print_version
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from utils.sub.mod3 import print_version
#
# File ~\Documents\ax_study\02_PYTHON\chapter06\utils\sub\mod3.py:4
#       1 # from chapter06.mod1 import VERSION
#       2 # 모듈이 있는 정체 경로
# ----> 4 from ....chapter06.mod1 import VERSION
#       6 def devide(num1, num2):
#       7     return num1 / num2
#
# ImportError: attempted relative import beyond top-level package

# %%
import mod1
# Out:
# 모듈명: mod1
# 결과: 30

# %%
from game import lol

# %%
import game
# Out:
# 공통 초기화 작업을 수행합니다....

# %%
game.common_func()
# Out:
# '공통 기능'

# %%
from game import *

lol.LOL
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from game import *
#       2
#       3 lol.LOL
#
# File ~\Documents\ax_study\02_PYTHON\chapter06\game\__init__.py:1
# ----> 1 import lol
#       3 print("공통 초기화 작업을 수행합니다....")
#       5 def common_func():
#
# ModuleNotFoundError: No module named 'lol'

# %%
from game import *

game.lol.LOL
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from game import *
#       2
#       3 game.lol.LOL
#
# File ~\Documents\ax_study\02_PYTHON\chapter06\game\__init__.py:1
# ----> 1 from lol import LOL
#       3 print("공통 초기화 작업을 수행합니다....")
#       5 def common_func():
#
# ModuleNotFoundError: No module named 'lol'

# %%
import

# %%
song = ["drowning", "honey", "lemonade"]
it = iter(song)
it

# %%
next(it)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 next(it)
#
# StopIteration:

# %%
def generate_fight():

    print("대박")
    yield 

    print("사건")
    yield

    print("성공")
    yield

# %%
gen = generate_fight()
gen
# Out:
# <generator object generate_fight at 0x000001988715E380>

# %%
next(gen)
# Out:
# 성공

# %%
import sys

# %%
comp = [nums * nums for nums in range(50001)]
gen = (nums * nums for nums in range(50001))

list_size = sys.getsizeof(comp)
gen_size = sys.getsizeof(gen)

print(f"리스트 컴프리헨션 메모리 용량: {list_size}")
print(f"제너레이터 컴프리헨션 메모리 용량: {gen_size}")
# Out:
# 리스트 컴프리헨션 메모리 용량: 444376
# 제너레이터 컴프리헨션 메모리 용량: 200

# %%
import random

# %%
Lotto = random.randint(1, 6)
print("Lotto번호는", Lotto)
# Out:
# Lotto번호는 1

# %%
import datetime

# %%
dayday = datetime.datetime.now()

# %%
today = dayday.strftime("%y%y-%m-%d")

# %%
print("오늘의 날짜는:", today)
# Out:
# 오늘의 날짜는: 2626-08-14

# %%
import datetime as d

# %%
d = datetime.datetime.now()

# %%
today = d.strftime("%H시-%M분-%S초")

# %%
print("현재 시각은", today)
# Out:
# 현재 시각은 17시-29분-11초

# %%
def message_store():
    storage=""

    def add_message(message):
        
        nonlocal storage
