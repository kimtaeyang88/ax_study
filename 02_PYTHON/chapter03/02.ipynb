# %%
user = {
    "email": "test@test.org", 
    "password": "1234", 
    "name": "김철수"
    }

# %%
user['mobile'] = "010-1000-1000"

user
# Out:
# {'email': 'test@test.org',
#  'password': '1234',
#  'name': '김철수',
#  'mobile': '010-1000-1000'}

# %%
user['name']
# Out:
# '김철수'

# %%
user.keys()
# Out:
# dict_keys(['email', 'password', 'name', 'mobile'])

# %%
user.values()
# Out:
# dict_values(['test@test.org', '1234', '김철수', '010-1000-1000'])

# %%
user.items()
# Out:
# dict_items([('email', 'test@test.org'), ('password', '1234'), ('name', '김철수'), ('mobile', '010-1000-1000')])

# %%
del user['mobile']

# %%
user
# Out:
# {'email': 'test@test.org', 'password': '1234', 'name': '김철수'}

# %%
a={10, 10 , 10, 20, 30}
a
# Out:
# {10, 20, 30}

# %%
a = {10, 20, 30, 40}
b = {30, 40, 50, 60}

print("합집합", a | b)
print("교집합", a & b)
print("차집합0", a - b)
print("대칭차집합", a ^ b)
# Out:
# 합집합 {40, 10, 50, 20, 60, 30}
# 교집합 {40, 30}
# 차집합0 {10, 20}
# 대칭차집합 {10, 50, 20, 60}

# %%
fruits = ['apple', 'banana', 'cherry']
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits[1] = 'blueberry'
fruits
# Out:
# ['apple', 'blueberry', 'cherry']

# %%
colors = ('red', 'green', 'blue')
colors
# Out:
# ('red', 'green', 'blue')

# %%
colors[-1]
# Out:
# 'blue'

# %%
group1 = [1, 2]
group2 = [3, 4]
group1 + group2
# Out:
# [1, 2, 3, 4]

# %%
user_roles = ['admin', 'editor', 'member']
user_roles
# Out:
# ['admin', 'editor', 'member']

# %%
'admin' in user_roles
# Out:
# True

# %%
numbers = [0, 1, 2, 3, 4, 5]
numbers
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
numbers[1:4]
# Out:
# [1, 2, 3]

# %%
numbers = [10, 20, 30, 40]
numbers
# Out:
# [10, 20, 30, 40]

# %%
first, *others = [10, 20, 30, 40]
print(first)
print(others)
# Out:
# 10
# [20, 30, 40]

# %%
count = 10

# %%
count *= 5

# %%
print(count)
# Out:
# 50

# %%
result = False and 500//0

# %%
print(result)
# Out:
# False

# %%
user_info = {
    "name": "Sparta",
    "age": "20"
}
user_info
# Out:
# {'name': 'Sparta', 'age': '20'}

# %%
user_info["age"]=21
user_info
# Out:
# {'name': 'Sparta', 'age': 21}

# %%
user_info["role"]="admin"
user_info
# Out:
# {'name': 'Sparta', 'age': 21, 'role': 'admin'}

# %%
user_info.get('phone', '010-0000-0000')
# Out:
# '010-0000-0000'

# %%
raw_emails =["a@sparta.com", "b@sparta.com", "a@sparta.com"]
raw_emails
# Out:
# ['a@sparta.com', 'b@sparta.com', 'a@sparta.com']

# %%
refined_emails = set(raw_emails)
refined_emails = list(refined_emails)
refined_emails
# Out:
# ['a@sparta.com', 'b@sparta.com']

# %%
menu = {'coffe' : 4000, 'tea' : 4500}
menu
# Out:
# {'coffe': 4000, 'tea': 4500}

# %%
print(menu.keys())
# Out:
# dict_keys(['coffe', 'tea'])

# %%
print(menu.values())
# Out:
# dict_values([4000, 4500])

# %%
set_a = {1,2,3}
set_b = {3,4,5}
set_a, set_b
# Out:
# ({1, 2, 3}, {3, 4, 5})

# %%
print(set_a & set_b)
# Out:
# {3}
