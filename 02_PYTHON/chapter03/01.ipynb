# %%
fruits= ['apple', 'orange', 'banana']

# %%
fruit1 = fruits[1]

# %%
fruits[1] = "오렌지"
fruits
# Out:
# ['apple', '오렌지', 'banana']

# %%
fruits.append("melon")
fruits
# Out:
# ['apple', '오렌지', 'banana', 'melon']

# %%
fruits_copy = fruits
fruits_copy[1] = 'orange'
fruits_copy
# Out:
# ['apple', 'orange', 'banana', 'melon']

# %%
print(fruits)
print(fruits_copy)
# Out:
# ['apple', 'orange', 'banana', 'melon']
# ['apple', 'orange', 'banana', 'melon']

# %%
fruits.extend(['Cherry', 'watermelon'])
fruits
# Out:
# ['orange', 'banana', 'apple', 'Cherry', 'watermelon']

# %%
fruits = ["apple"]
print("추가 전(+):", id(fruits))
fruits = fruits + ["orange", "banana"]
print("추가 후(+):", id(fruits))

fruits
# Out:
# 추가 전(+): 1509906023936
# 추가 후(+): 1509906121536
# ['apple', 'orange', 'banana']

# %%
fruits_extend = ["apple"]
print("추가 전(extend):", id(fruits_extend))

fruits_extend.extend(["orange", "banana"])
print("추가 후(extend):", id(fruits_extend))
# Out:
# 추가 전(extend): 1509906030784
# 추가 후(extend): 1509906030784

# %%
fruits.sort(reverse=True)
fruits
# Out:
# ['orange', 'banana', 'apple']

# %%
fruits = ('apple', 'orange')
fruits
# Out:
# ('apple', 'orange')

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[0] = '사과'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 fruits[0] = '사과'
#
# TypeError: 'tuple' object does not support item assignment

# %%
fruits2 = fruits + ('banana', 'watermelon')
fruits2
# Out:
# ('apple', 'orange', 'banana', 'banana', 'watermelon')

# %%
print

# %%
fruits = 'apple', 'orange', 'banana'
fruits, type(fruits)
# Out:
# (('apple', 'orange', 'banana'), tuple)

# %%
apple, orange, banana = fruits

apple, orange, banana
# Out:
# ('apple', 'orange', 'banana')

# %%
a=fruits[0]
b=fruits[1]
a, b
# Out:
# ('apple', 'orange')

# %%
a, b, c = ('apple', 'orange', 'banana')
a, c
# Out:
# ('apple', 'banana')

# %%
a, b, _ = fruits
a, b
# Out:
# ('apple', 'orange')

# %%
a, b, *rest = (1, 2, 3, 4, 5, 6, 7)
print(a, b)
print(rest)
# Out:
# 1 2
# [3, 4, 5, 6, 7]

# %%
num1 = 10
num2 = 20

# num1과 num2의 값을 서로 바꾸시오.
tmp = num2
num2 = num1
num1 = tmp

num1, num2
# Out:
# (20, 10)

# %%
num1 = 10
num2 = 20

num1, num2 = num2, num1

num1, num2
# Out:
# (20, 10)

# %%
numbers = [100, 200, 300]
numbers[2], numbers[-1], numbers[-2]
# Out:
# (300, 300, 200)

# %%
numbers_3_6 = numbers[2:-4]
numbers
# Out:
# [100, 200, 300]

# %%
numbers_flip = numbers[::-1]
print(numbers)
numbers_flip
# Out:
# [100, 200, 300]
# [300, 200, 100]

# %%
fruits = ['apple', 'banana', 'orange']
fruits_copy = fruits[:]
print("fruits", fruits, id(fruits))
print("fruits_copy", fruits_copy, id(fruits))
# Out:
# fruits ['apple', 'banana', 'orange'] 1509905883072
# fruits_copy ['apple', 'banana', 'orange'] 1509905883072
# fruits_copy ['apple', 'banana', 'orange'] 1509905890688

# %%
ones = [1] * 3

# %%
ones
# Out:
# [1, 1, 1]

# %%
fruits = ["사과", "오렌지", "바나나"]
'오렌지' in fruits
# Out:
# True

# %%
'오렌지' not in fruits
# Out:
# False

# %%
len(fruits)
# Out:
# 3

# %%
tuple_nums = 10, 20, 30
# tuple_nums[1] *= 2

list_nums = list(tuple_nums)
list_nums[1] *= 2

list_nums
# Out:
# [10, 40, 30]

# %%
message = "one two three"
message[4:7]
# Out:
# 'two'

# %%
message[4:7]
# Out:
# 'two'

# %%
x = [0, 1, 2, 'apple', 'melon', True, False, [3, 4, 5], (6,7,8,)]

# %%
# x2 = x[:]
x2 = x.copy()
x2
# Out:
# [0, 1, 2, 'apple', 'melon', True, False, [3, 4, 5], (6, 7, 8)]

# %%
x2[1] = 10
x2, x
# Out:
# ([0, 10, 2, 'apple', 'melon', True, False, [3, 4, 5], (6, 7, 8)],
#  [0, 1, 2, 'apple', 'melon', True, False, [3, 4, 5], (6, 7, 8)])

# %%
x2[-2][2] = 50

# %%
x2, x
# Out:
# ([0, 10, 2, 'apple', 'melon', True, False, [3, 4, 50], (6, 7, 8)],
#  [0, 1, 2, 'apple', 'melon', True, False, [3, 4, 50], (6, 7, 8)])

# %%
mobile = get("mobile", "없음")
type(mobile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 mobile = get("mobile", "없음")
#       2 type(mobile)
#
# NameError: name 'get' is not defined
